# %%
import app_functions as af
import pandas as pd
import custom_calculations as calcs

# %%
prices = pd.read_csv(r'Z:\Interés Departamental\Model Portfolio\Hugo\Ranking DIP European Equities\copia 12-04-2023\data\vertical_dowload_files\PriceClose.csv',index_col=0)

# %%
one_month_momentum = calcs.rate_of_change(prices,1)
three_month_momentum = calcs.rate_of_change(prices,3)
six_month_momentum = calcs.rate_of_change(prices,6)
nine_month_momentum = calcs.rate_of_change(prices,9)
twelve_month_momentum = calcs.rate_of_change(prices,12)

# %%
n_quantiles = 4

# %%
one_month_ranks = af.rank_data(one_month_momentum,n_quantiles,'low')
three_month_ranks = af.rank_data(three_month_momentum,n_quantiles,'high')
six_month_ranks = af.rank_data(six_month_momentum,n_quantiles,'high')
nine_month_ranks = af.rank_data(nine_month_momentum,n_quantiles,'high')
twelve_month_ranks = af.rank_data(twelve_month_momentum,n_quantiles,'high')
# Out:
# 2023-05-16 13:02:35.089
# ...
#   command:
#
#     streamlit run c:\Users\hugo.perezdealbeniz\AppData\Local\miniconda3\envs\refinitiv\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# Failed to rank:
#  []
# Failed to rank:
#  ['2000-04-01']
# Failed to rank:
#  []
# Failed to rank:
#  ['2000-10-01']
# Failed to rank:
#  []

# %%
prices
# Out:
#             1COV.DE     1U1.DE     A2.MI  A3M.MC  AAAA.L^C21  AAH.AS^D08  \
# 2000-01-01      NaN        NaN       NaN     NaN         NaN         NaN
# 2000-02-01      NaN   8.164804  4.296516     NaN         NaN       20.61
# 2000-03-01      NaN  11.218151  6.288860     NaN         NaN       21.50
# 2000-04-01      NaN  10.725364  5.380019     NaN         NaN       23.29
# 2000-05-01      NaN   9.179365  4.683340     NaN         NaN       22.65
# ...             ...        ...       ...     ...         ...         ...
# 2022-09-01    30.12  16.000000  1.119500   2.730         NaN         NaN
# 2022-10-01    29.54  13.570000  0.999800   2.636         NaN         NaN
# 2022-11-01    34.44  13.340000  1.122000   2.920         NaN         NaN
# 2022-12-01    38.17  13.770000  1.277000   3.350         NaN         NaN
# 2023-01-01    36.55  11.600000  1.245000   3.192         NaN         NaN
#
#                AAK.ST      AAL.L  AALB.AS  AB.L^G07  ...     YAR.OL    YIT.HE  \
# ...

# %%
(0.999800-1.119500)/1.119500
# Out:
# -0.10692273336310847

# %%
one_month_momentum
# Out:
#              1COV.DE    1U1.DE     A2.MI    A3M.MC  AAAA.L^C21  AAH.AS^D08  \
# 2000-01-01       NaN       NaN       NaN       NaN         NaN         NaN
# 2000-02-01       NaN       NaN       NaN       NaN         NaN         NaN
# 2000-03-01       NaN  0.373964  0.463712       NaN         NaN    0.043183
# 2000-04-01       NaN -0.043928 -0.144516       NaN         NaN    0.083256
# 2000-05-01       NaN -0.144144 -0.129494       NaN         NaN   -0.027480
# ...              ...       ...       ...       ...         ...         ...
# 2022-09-01 -0.093590 -0.054932 -0.108678 -0.090000         NaN         NaN
# 2022-10-01 -0.019256 -0.151875 -0.106923 -0.034432         NaN         NaN
# 2022-11-01  0.165877 -0.016949  0.122224  0.107739         NaN         NaN
# 2022-12-01  0.108304  0.032234  0.138146  0.147260         NaN         NaN
# 2023-01-01 -0.042442 -0.157589 -0.025059 -0.047164         NaN         NaN
#
# ...

# %%
one_month_ranks
# Out:
#             1COV.DE  1U1.DE  A2.MI  A3M.MC  AAAA.L^C21  AAH.AS^D08  AAK.ST  \
# 2000-03-01      NaN     4.0    4.0     NaN         NaN         3.0     NaN
# 2000-04-01      NaN     2.0    1.0     NaN         NaN         3.0     NaN
# 2000-05-01      NaN     1.0    1.0     NaN         NaN         2.0     NaN
# 2000-06-01      NaN     1.0    1.0     NaN         NaN         4.0     NaN
# 2000-07-01      NaN     1.0    2.0     NaN         NaN         3.0     NaN
# ...             ...     ...    ...     ...         ...         ...     ...
# 2022-09-01      2.0     3.0    2.0     2.0         NaN         NaN     2.0
# 2022-10-01      4.0     1.0    2.0     4.0         NaN         NaN     2.0
# 2022-11-01      4.0     1.0    4.0     3.0         NaN         NaN     3.0
# 2022-12-01      3.0     2.0    4.0     4.0         NaN         NaN     3.0
# 2023-01-01      2.0     1.0    3.0     2.0         NaN         NaN     3.0
#
# ...

# %%
data_dict = {
    'one_month_momentum':one_month_momentum,
    'three_month_momentum':three_month_momentum,
    'six_month_momentum':six_month_momentum,
    'nine_month_momentum':nine_month_momentum,
    'twelve_month_momentum':twelve_month_momentum,
             }

# %%
weights_df = pd.DataFrame(dict(Factor=data_dict.keys(), Weight=0.2, Type=['low','high','high','high','high']))
weights_df
# Out:
#                   Factor  Weight  Type
# 0     one_month_momentum     0.2   low
# 1   three_month_momentum     0.2  high
# 2     six_month_momentum     0.2  high
# 3    nine_month_momentum     0.2  high
# 4  twelve_month_momentum     0.2  high

# %%
calculado = af.multi_factor_ranking(weights_df,data_dict,n_quantiles,None)
# Out:
# c:\Users\hugo.perezdealbeniz\Documents\GitHub\ranking_DIP_european_equities\app\app_functions.py:219: UserWarning: No mask was provided.
#   warn("No mask was provided.")
# Failed to rank:
#  []
# c:\Users\hugo.perezdealbeniz\Documents\GitHub\ranking_DIP_european_equities\app\app_functions.py:219: UserWarning: No mask was provided.
#   warn("No mask was provided.")
# Failed to rank:
#  ['2000-04-01']
# c:\Users\hugo.perezdealbeniz\Documents\GitHub\ranking_DIP_european_equities\app\app_functions.py:219: UserWarning: No mask was provided.
#   warn("No mask was provided.")
# Failed to rank:
#  []
# c:\Users\hugo.perezdealbeniz\Documents\GitHub\ranking_DIP_european_equities\app\app_functions.py:219: UserWarning: No mask was provided.
#   warn("No mask was provided.")
# Failed to rank:
#  ['2000-10-01']
# c:\Users\hugo.perezdealbeniz\Documents\GitHub\ranking_DIP_european_equities\app\app_functions.py:219: UserWarning: No mask was provided.
#   warn("No mask was provided.")
# ...

# %%
calculado
# Out:
#             1COV.DE  1U1.DE  A2.MI  A3M.MC  AAAA.L^C21  AAH.AS^D08  AAK.ST  \
# 2001-02-01      NaN    0.72   0.68     NaN         NaN        0.40     NaN
# 2001-03-01      NaN    0.68   0.68     NaN         NaN        0.48     NaN
# 2001-04-01      NaN    0.60   0.76     NaN         NaN        0.56     NaN
# 2001-05-01      NaN    0.68   0.72     NaN         NaN        0.64     NaN
# 2001-06-01      NaN    0.68   0.64     NaN         NaN        0.56     NaN
# ...             ...     ...    ...     ...         ...         ...     ...
# 2022-09-01     0.72    0.76   0.72    0.64         NaN         NaN    0.44
# 2022-10-01     0.76    0.68   0.72    0.64         NaN         NaN    0.52
# 2022-11-01     0.64    0.68   0.72    0.48         NaN         NaN    0.52
# 2022-12-01     0.52    0.72   0.60    0.52         NaN         NaN    0.44
# 2023-01-01     0.44    0.68   0.48    0.44         NaN         NaN    0.44
#
# ...
