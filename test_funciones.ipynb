# %%
from code_in_production.app_functions import get_data, rank_data, plot_NAV_absoluto,plot_NAV_relativo,plot_rentabilidad_media,plot_sharpe,plot_Volatilidad
# Out:
# 2023-02-21 13:04:24,899 P[5988] [MainThread 16776] Error: no proxy address identified.
# Check if Eikon Desktop or Eikon API Proxy is running.
# 2023-02-21 13:04:24,902 P[5988] [MainThread 16776] Error on handshake url http://127.0.0.1:None/api/handshake : UnsupportedProtocol("Request URL is missing an 'http://' or 'https://' protocol.")
# 2023-02-21 13:04:24,904 P[5988] [MainThread 16776] Error on handshake url http://127.0.0.1:None/api/handshake : UnsupportedProtocol("Request URL is missing an 'http://' or 'https://' protocol.")
# 2023-02-21 13:04:24,905 P[5988] [MainThread 16776] Port number was not identified, cannot send any request

# %%
pivoted_df,notna_graph,errors = get_data(['TR.EVToSales','TR.EVToSales.date'],desired_field_name='EVToSales')
# Out:
#  27%|██▋       | 75/277 [17:55<57:49, 17.18s/it]  2023-02-14 12:08:05,041 P[11192] [MainThread 13820] Backend error. 400 Bad Request
# 2023-02-14 12:08:05,042 P[11192] [MainThread 13820] HTTP request failed: EikonError-Backend error. 400 Bad Request
#  27%|██▋       | 76/277 [18:13<58:37, 17.50s/it]
# failed for 2006-04-01
#  31%|███       | 86/277 [21:04<51:55, 16.31s/it]  2023-02-14 12:11:14,495 P[11192] [MainThread 13820] Backend error. 400 Bad Request
# 2023-02-14 12:11:14,496 P[11192] [MainThread 13820] HTTP request failed: EikonError-Backend error. 400 Bad Request
#  31%|███▏      | 87/277 [21:22<53:35, 16.92s/it]
# failed for 2007-03-01
# 100%|██████████| 277/277 [34:21<00:00,  7.44s/it]

# %%
errors[0].keys()
# Out:
# dict_keys(['2006-04-01', '2007-03-01'])

# %%
rentabilidades_dict = rank_data(pivoted_df,'Z:\Interés Departamental\Model Portfolio\Hugo\Ranking DIP European Equities\Reuters Eikon\data\Final Data\PriceClose.csv')

# %%
import matplotlib.pyplot as plt

# %%
plt.show(ax4)

# %%
ax = plot_NAV_relativo(rentabilidades_dict)

# %%
ax.set_title('plt prueba')
plt.show()

# %%
d = dict(((1,2),(3,4),(5,6)))

# %%
if not not d:
    print(d)
# Out:
# {1: 2, 3: 4, 5: 6}

# %%
input('yes or no')
# Out:
# 'yes'
