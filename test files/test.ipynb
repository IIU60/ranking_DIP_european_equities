# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import app_functions as af
import plots as pl

# %%
df = pd.read_csv(r'C:\Users\hugo.perezdealbeniz\Desktop\Ranking DIP European Equities\ReutersEikon\data\vertical_dowload_files\CompanyMarketCapitalization.csv',index_col = 0)
mask = pd.read_csv(r'C:\Users\hugo.perezdealbeniz\Desktop\Ranking DIP European Equities\ReutersEikon\data\PriceClose_vertical\monthly_constituents_filter.csv',index_col=0)
masked_df = af.apply_mask(df,mask)

# %%
masked_df
# Out:
#                  1COV.DE  1U1.DE         A2.MI  A3M.MC  AAAA.L^C21  \
# 2000-01-01           NaN     NaN           NaN     NaN         NaN
# 2000-02-01           NaN     NaN  7.733932e+09     NaN         NaN
# 2000-03-01           NaN     NaN  1.132025e+10     NaN         NaN
# 2000-04-01           NaN     NaN  9.684289e+09     NaN         NaN
# 2000-05-01           NaN     NaN  8.430234e+09     NaN         NaN
# ...                  ...     ...           ...     ...         ...
# 2022-09-01  5.819184e+09     NaN  3.507287e+09     NaN         NaN
# 2022-10-01  5.707128e+09     NaN  3.132279e+09     NaN         NaN
# 2022-11-01  6.653808e+09     NaN  3.515120e+09     NaN         NaN
# 2022-12-01  7.374444e+09     NaN  4.000720e+09     NaN         NaN
# 2023-01-01  6.900340e+09     NaN  3.811471e+09     NaN         NaN
#
#                   AAK.ST         AAL.L       AALB.AS        ABBN.S  \
# 2000-01-01           NaN           NaN           NaN           NaN
# ...

# %%
pl.notna_plot(df)

# %%
pl.notna_plot(masked_df)

# %%
data_fp = r'C:\Users\hugo.perezdealbeniz\Desktop\Ranking DIP European Equities\ReutersEikon\data\vertical_dowload_files'

# %%
good_dfs,bad_dfs = af.filter_data(data_fp,expected_stocks_per_date=600,mask=mask)
# Out:
# [autoreload of app_functions failed: Traceback (most recent call last):
#   File "c:\Users\hugo.perezdealbeniz\AppData\Local\miniconda3\envs\refinitiv\lib\site-packages\IPython\extensions\autoreload.py", line 273, in check
#     superreload(m, reload, self.old_objects)
#   File "c:\Users\hugo.perezdealbeniz\AppData\Local\miniconda3\envs\refinitiv\lib\site-packages\IPython\extensions\autoreload.py", line 496, in superreload
#     update_generic(old_obj, new_obj)
#   File "c:\Users\hugo.perezdealbeniz\AppData\Local\miniconda3\envs\refinitiv\lib\site-packages\IPython\extensions\autoreload.py", line 393, in update_generic
#     update(a, b)
#   File "c:\Users\hugo.perezdealbeniz\AppData\Local\miniconda3\envs\refinitiv\lib\site-packages\IPython\extensions\autoreload.py", line 305, in update_function
#     setattr(old, name, getattr(new, name))
# ValueError: apply_mask() requires a code object with 0 free vars, not 1
# ]

# %%
bad_dfs.keys()
# Out:
# dict_keys(['CompanyMarketCapitalization', 'HistPEG', 'NetDebtToEBITDA', 'NetDebtToEV'])

# %%
import os
import matplotlib.pyplot as plt

for i in os.listdir(data_fp):
    df = pd.read_csv(data_fp+f'\{i}')
    print(i)
    plt.plot(df.notna().sum(axis=1))
# Out:
# CompanyMarketCapitalization.csv
# EV.csv
# EVTOEBIT.csv
# EVTOEBITDA.csv
# EVTOOperatingCashFlow.csv
# EVToSales.csv
# HistPEG.csv
# NetDebtToEBITDA.csv
# NetDebtToEV.csv
# PE.csv
# PriceClose.csv
# PriceToBVPerShare.csv
# PriceToCFPerShare.csv
# PriceToSalesPerShare.csv
# PriceToTangBVPerShare.csv
# TotalDebtToEBITDA.csv
# TotalDebtToEV.csv

# %%
import os
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for i in os.listdir(data_fp):
    df = pd.read_csv(data_fp+f'\{i}',index_col=0)
    df = af.apply_mask(df,mask)
    plt.plot(df.notna().sum(axis=1),label=i)
    plt.hlines([0.8*600],0,277)
    plt.legend()
# Out:
# 2023-04-13 12:38:30.011 Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2023-04-13 12:38:30.033 Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# CompanyMarketCapitalization.csv
# 2023-04-13 12:38:30.245 Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2023-04-13 12:38:30.272 Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# EV.csv
# EVTOEBIT.csv
# ...

# %%
df
# Out:
#               1COV.DE  1U1.DE      A2.MI  A3M.MC  AAAA.L^C21  AAH.AS^D08  \
# 2000-01-01        NaN     NaN        NaN     NaN         NaN         NaN
# 2000-02-01        NaN     NaN        NaN     NaN         NaN         NaN
# 2000-03-01        NaN     NaN        NaN     NaN         NaN         NaN
# 2000-04-01        NaN     NaN        NaN     NaN         NaN         NaN
# 2000-05-01        NaN     NaN        NaN     NaN         NaN         NaN
# ...               ...     ...        ...     ...         ...         ...
# 2022-09-01  36.532124     NaN  71.532938     NaN         NaN         NaN
# 2022-10-01  37.011747     NaN  74.640774     NaN         NaN         NaN
# 2022-11-01  33.358411     NaN  71.338433     NaN         NaN         NaN
# 2022-12-01  31.020061     NaN  67.547753     NaN         NaN         NaN
# 2023-01-01  31.994109     NaN  81.211627     NaN         NaN         NaN
#
#                AAK.ST      AAL.L    AALB.AS  AB.L^G07  ...     YAR.OL  YIT.HE  \
# ...
