# %%
import eikon as ek
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ek.set_app_key('89915a3b58874e1599870c6ecc45d6edd6344f8c')

# %%
df, err = ek.get_data('0#.STOXX', fields=['TR.ROCEActValue','TR.ROCEActValue.periodenddate'],parameters={'SDate':'20000101','EDate':'20230101','Frq':'FI','Period':'FY0'})

# %%
df.rename(columns={'Period End Date':'Date', 'Return On Capital Employed - Actual':'ROCE'}, inplace=True)

# %%
df
# Out:
#       Instrument   ROCE        Date
# 0        BOUY.PA   <NA>
# 48       BOUY.PA    5.0  2014-12-31
# 52       BOUY.PA   5.58  2015-12-31
# 56       BOUY.PA   5.27  2016-12-31
# 60       BOUY.PA    7.8  2017-12-31
# ...          ...    ...         ...
# 33240     ENI.MI   6.42  2017-12-31
# 33244     ENI.MI   11.1  2018-12-31
# 33248     ENI.MI  9.169  2019-12-31
# 33252     ENI.MI    2.2  2020-12-31
# 33256     ENI.MI  10.19  2021-12-31
#
# [4465 rows x 3 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.drop_duplicates(inplace=True)

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=df, x='Date',y='ROCE',hue='Instrument',legend=False)
plt.xticks(rotation=-45,fontsize=10,ha='left',rotation_mode='anchor')
# Out:
# (array([15706., 16071., 16436., 16801., 17167., 17532., 17897., 18262.,
#         18628., 18993., 19358.]),
#  [Text(15706.0, 0, '2013'),
#   Text(16071.0, 0, '2014'),
#   Text(16436.0, 0, '2015'),
#   Text(16801.0, 0, '2016'),
#   Text(17167.0, 0, '2017'),
#   Text(17532.0, 0, '2018'),
#   Text(17897.0, 0, '2019'),
#   Text(18262.0, 0, '2020'),
#   Text(18628.0, 0, '2021'),
#   Text(18993.0, 0, '2022'),
#   Text(19358.0, 0, '2023')])

# %%
df.pivot(index='Date',columns='Instrument',values='ROCE').dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# ...
