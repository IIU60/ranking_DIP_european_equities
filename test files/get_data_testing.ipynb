# %%
import code_in_production.app_functions as af
import pandas as pd
import eikon as ek
import matplotlib.pyplot as plt

# %%
ek.get_data('NESN.S','TR.MemberIndexRic')
# Out:
# (   Instrument       Index RIC
#  0      NESN.S           .SX3V
#  1      NESN.S           .SSMI
#  2      NESN.S   .TRXFLDCHPN12
#  3      NESN.S           .SX3L
#  4      NESN.S  .TRXFLDEXPUNCY
#  ..        ...             ...
#  59     NESN.S     .TRXFLDGLPU
#  60     NESN.S  .TRXFLDGATUUSD
#  61     NESN.S     .TRXFLDGAPU
#  62     NESN.S  .TRXFLDGAPUUSD
#  63     NESN.S     .TRXFLDGLTL
#
#  [64 rows x 2 columns],
#  None)

# %%
indicador = 'TR.EPSActValue(Period=FQ0,Curn=EUR)'
EPSActValue_pivoted, errors = af.get_data([indicador,indicador+'.date'], 'EPSActValue_FQ0')
# Out:
# 100%|██████████| 277/277 [11:57<00:00,  2.59s/it]

# %%
EPSActValue_pivoted
# Out:
# Instrument  1COV.DE       1U1.DE        A2.MI         A3M.MC        \
# CallDate
# 2000-01-01          <NA>          <NA>          <NA>          <NA>
# 2000-02-01          <NA>          <NA>          <NA>          <NA>
# 2000-03-01          <NA>          <NA>          <NA>          <NA>
# 2000-04-01          <NA>          <NA>          <NA>          <NA>
# 2000-05-01          <NA>          <NA>          <NA>          <NA>
# ...                  ...           ...           ...           ...
# 2022-09-01          1.04          <NA>          <NA>          <NA>
# 2022-10-01          1.04          <NA>          <NA>          <NA>
# 2022-11-01          0.06          <NA>          <NA>          <NA>
# 2022-12-01          0.06          <NA>          <NA>          <NA>
# 2023-01-01          0.06          <NA>          <NA>          <NA>
#
# Instrument  AAAA.L^C21    AAH.AS^D08    AAK.ST        AAL.L         \
# CallDate
# 2000-01-01          <NA>          <NA>          <NA>          <NA>
# ...

# %%
pd.read_csv('Z:/Interés Departamental/Model Portfolio/Hugo/Ranking DIP European Equities/Reuters Eikon/data/raw_data/raw_EPSActValue_FY0.csv')
# Out:
#         Instrument                  Date    CallDate  \
# 0            III.L  1999-06-14T16:27:51Z  2000-01-01
# 1            A2.MI  1999-03-17T17:41:00Z  2000-01-01
# 2           ABBN.S  1999-02-08T05:00:00Z  2000-01-01
# 3       ABE.MC^H18  1999-03-03T05:00:00Z  2000-01-01
# 4            ABF.L  1999-11-08T14:44:27Z  2000-01-01
# ...            ...                   ...         ...
# 166038      WLN.PA  2022-02-22T14:16:00Z  2023-01-01
# 166039       WPP.L  2022-02-24T07:00:00Z  2023-01-01
# 166040      YAR.OL  2022-02-08T07:00:00Z  2023-01-01
# 166041     ZALG.DE  2022-03-01T06:00:00Z  2023-01-01
# 166042      ZURN.S  2022-02-10T05:50:00Z  2023-01-01
#
#         Earnings Per Share - Actual
# 0                          0.262282
# 1                          0.060000
# 2                          0.770052
# 3                          0.239750
# 4                          0.494055
# ...                             ...
# 166038                     2.230000
# ...

# %%
EPSActValue_FYO_pivoted = pd.read_csv('data/pivoted_data/pivoted_EPSActValue_FY0.csv',index_col=0)
EPSActValue_pivoted = pd.read_csv('data/pivoted_data/pivoted_EPSActValue_FQ0.csv',index_col=0)

ruta_precios = 'Z:\Interés Departamental\Model Portfolio\Hugo\Ranking DIP European Equities\Reuters Eikon\data\Final Data\PriceClose.csv'
rentabilidades_dict_FY0, notna_graph_FY0 = af.rank_data(EPSActValue_FYO_pivoted,ruta_precios)
rentabilidades_dict_FQ0, notna_graph_FQ0 = af.rank_data(EPSActValue_pivoted,ruta_precios)

# %%
notna_graph_FQ0

# %%
notna_graph_FY0

# %%
nav_abs_FY0 = af.plot_NAV_absoluto(rentabilidades_dict_FY0)
nav_rel_FY0 = af.plot_NAV_relativo(rentabilidades_dict_FY0)
rent_med_FY0 = af.plot_rentabilidad_media(rentabilidades_dict_FY0)
sharpe_FY0 = af.plot_sharpe(rentabilidades_dict_FY0)
vol_FY0 = af.plot_Volatilidad(rentabilidades_dict_FY0)

# %%
nav_abs_FQ0 = af.plot_NAV_absoluto(rentabilidades_dict_FQ0)
nav_rel_FQ0 = af.plot_NAV_relativo(rentabilidades_dict_FQ0)
rent_med_FQ0 = af.plot_rentabilidad_media(rentabilidades_dict_FQ0)
sharpe_FQ0 = af.plot_sharpe(rentabilidades_dict_FQ0)
vol_FQ0 = af.plot_Volatilidad(rentabilidades_dict_FQ0)

# %%
nav_abs_FY0

# %%
nav_abs_FQ0

# %%
nav_rel_FQ0

# %%
rent_med_FQ0

# %%
vol_FQ0

# %%
sharpe
