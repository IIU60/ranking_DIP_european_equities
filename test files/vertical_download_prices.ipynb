# %%
import eikon as ek
import pandas as pd
import numpy as np
from tqdm import tqdm

ek.set_app_key('89915a3b58874e1599870c6ecc45d6edd6344f8c')

# %% [markdown]
# ## Download
# ---

# %%
long_string = '''III.L
1COV.DE
1U1.DE
A2.MI
A3M.MC
AAAA.L^C21
AAH.AS^D08
AAK.ST
AAL.L
AALB.AS
AB.L^G07
ABBN.S
ABBPa.ST^G99
ABBPb.ST^G99
ABBZa.S^K99
ABDN.L
ABE.MC^H18
ABF.L
ABGek.MC^I22
ABI.BR
ABLX.BR^F18
ABNd.AS
ABP.L^H06
ACBr.AT
ACCP.PA
ACE.MI
ACKB.BR
ACLN.S
ACMI_p.MI^J98
ACR.MC^C04
ACS.MC
ACX.MC
AD.AS
ADDTb.ST
ADEA.OL
ADEA.OL^J19
ADEN.S
ADJ.DE
ADML.L
ADN.L^H17
ADP.PA
ADR.MI^C01
ADSGn.F
ADYEN.AS
ADZ.L^J00
AEGN.AS
AEGS.L^C13
AENA.MC
AFAr.AT^D01
AFRE.L^H15
AFRY.ST
AFXG.DE
AG.L^L02
AG1G.DE
AGA.L^I15
AGAa.ST^D00
AGAb.ST^D00
AGES.BR
AGFB.BR
AGFP.PA^J07
AGG.L^D05
AGGK.L^H21
AGL.MI
AGR.MC^J00
AGRP.L
AGS.MC^F10
AHT.L
AIBG.I
AICr.AT^L18
AIR.PA
AIRF.PA
AIRP.PA
AIXGn.DE
AKAST.OL
AKE.OL^B00
AKE.PA
AKRBP.OL
AKSOA.OL
AKTr.AT^L05
AKZO.AS
ALAr.AT^C14
ALATA.PA
ALB.MC
ALCC.S
ALEP.WA
ALFA.ST
ALFEN.AS
ALGETA.OL^C14
ALGr.AT^J07
ALIFb.ST
ALIVsdb.ST
ALKb.CO
ALLD.L^G05
ALLEI.ST
ALLFG.AS
ALLL.L^J08
ALLN.S
ALMB.BR^D05
ALNT.L^L15
ALPH.S^L19
ALSO.PA
ALT.MC^B08
ALTG.DE^H10
ALTT.PA^D20
ALUA.PA^K16
ALUSn.S^E01
ALVG.F
ALZI.MI^I09
AM.PA
AMA.MC
AMA.OL^B02
AMBUb.CO
AMCr.AT
AMEAS.HE^I19
AMFW.L^J17
AML.L^B16
AMPF.MI
AMS.MC^L05
AMS.S
AMS_r.S^C20
AMUN.PA
AMY.L^F03
ANA.MC
ANDR.VI
ANE.MC
ANGL.I^A09
ANL.L^K04
ANTO.L
AOO.BR
AOXG.DE
APAM.AS
APRr.AT^C13
APRR.PA^L12
ARDS.AS
AREVA.PA^H17
ARG.MC^A00
ARGX.BR
ARI.L^H10
ARJOb.ST
ARK.L^J09
ARLG.DE
ARM.L^I16
AROG.DE^C18
AROG.F^C18
ARYN.I^C21
ARYN.S
ASDO.ST^A02
ASF.PA^B07
ASHM.L
ASMI.AS
ASML.AS
ASRNc.AS^I01
ASRNL.AS
ASSAb.ST
ASSD.L^J99
ASTRa.ST^D99
ASTRb.ST^D99
AT1.DE
ATAB.VI^B02
ATCA.AS^A21
ATCB.AS^A21
VIV.PA
VIVr.AT^A11
VLLP.PA
VLOF.PA
VMFN.AS^B08
VMUK.L
VNAn.DE
VNUN.AS^G06
VOD.L
VOES.VI
VOLCARb.ST
VOLVa.ST
VOLVb.ST
VONN.S
VOPA.AS
VOWG.DE
VOWG.F
VOWG_p.DE
VPBN.S
VPC.L^J09
VPLAYb.ST
VRD.L^L06
VRLA.PA
VSVS.L
VTG.L^G10
VTSCn.DE
VTWRn.DE
VTYV.L
VWS.CO
VWSTc.AS^I03
WADG_p.DE^K07
WAFGn.DE
WALLb.ST
WBSV.VI
WCHG.DE
WCMG.DE^E11
WCRX.L^A05
WDIG.DE^A21
WDON.AS^A01
WDPP.BR
WEHA.AS
WEIR.L
WG.L
WIHL.ST
WING.DE^E19
WISEa.L
WITH.HE
WIZZ.L
WLB.L^D07
WLFD.VI
WLN.PA
WLSNc.AS
WLW.L^C09
WMb.ST^K06
WMH.L^D21
WMPY.L^G07
WOSG.L
WPG.L^A18
WPP.L
WRT1V.HE
WSML.L^C11
WTB.L
WTF_u.I^L10
WWH.L^J00
XAN.L^J07
XIOr.AT^F00
XTA.L^E13
YAR.OL
YIT.HE
YSO.LS
ZALG.DE
ZEL.MC^K15
ZIGGO.AS^L14
ZO1G.DE^A22
ZODC.PA^C18
ZOT.MC^E22
ZURN.S'''

# %%
constituents_list = long_string.split('\n')

# %%
fields = ['TR.PriceClose','TR.PriceClose.date','TR.PriceClose.calcdate']
parameters = {'SDate':'2000-01-01','EDate':'2023-01-01','Frq':'D','Curn':'EUR'}

# %%
from eikon import EikonError

# %%
fails = []
for instrument in failed_constituents: # tqdm(constituents_list[constituents_list.index(last_successful)+1:]):
    try:
        df, err = ek.get_data(instrument, fields, parameters)
        df.to_csv(f'C:/Users/hugo.perezdealbeniz/Desktop/Ranking DIP European Equities/ReutersEikon/data/PriceClose_vertical/raw_data/{instrument}.csv')
    except EikonError:
        fails.append(instrument)
        continue
    except AttributeError:
        fails.append(instrument)
        continue
    last_successful = instrument

# %%
last_successful
# Out:
# 'TLIT.MI'

# %%
from os import listdir

ls = listdir(r'..\data\PriceClose_vertical\raw_data')
ls = list(map(lambda x: x.strip('.csv'),ls))

# %%
failed_constituents = set(constituents_list) - set(ls)
failed_constituents
# Out:
# set()

# %% [markdown]
# ## Reconstruction
# ---

# %%
dir_fp = '../data/PriceClose_vertical/raw_data'
dfs_list = []
to_inspect = {}
for file in tqdm(listdir(dir_fp)):
    try:
        df = pd.read_csv(dir_fp + '/' + file)
        df = df.drop(columns=['Unnamed: 0','Calc Date'])
        df = df.dropna()
        df = df.drop_duplicates()
    except Exception as x:
        to_inspect[file] = x
        continue
    dfs_list.append(df)
# Out:
# 100%|██████████| 1825/1825 [00:37<00:00, 48.47it/s]

# %%
to_inspect
# Out:
# {'DEA.MI^C23.csv': KeyError("['Calc Date'] not found in axis"),
#  'UNI.CO^F00.csv': KeyError("['Calc Date'] not found in axis")}

# %%
tmp,err = ek.get_data('DEA.MI^C23.csv',fields,parameters)
tmp
# Out:
#              None  TR.PRICECLOSE  TR.PRICECLOSE.DATE  TR.PRICECLOSE.calcdate
# 0  DEA.MI^C23.csv           <NA>                <NA>                    <NA>

# %%
tmp = pd.read_csv(dir_fp + '/UNI.CO^F00.csv')
tmp
# Out:
#    Unnamed: 0  Unnamed: 1  TR.PRICECLOSE  TR.PRICECLOSE.DATE  \
# 0           0  UNI.CO^F00            NaN                 NaN
#
#    TR.PRICECLOSE.calcdate
# 0                     NaN

# %%
concat_df = pd.concat([tmp1,tmp2])
# Out:
#       Unnamed: 0 Instrument  Price Close                  Date   Calc Date
# 0              0    1COV.DE          NaN                   NaN  2000-01-03
# 1              1    1COV.DE          NaN                   NaN  2000-01-04
# 2              2    1COV.DE          NaN                   NaN  2000-01-05
# 3              3    1COV.DE          NaN                   NaN  2000-01-06
# 4              4    1COV.DE          NaN                   NaN  2000-01-07
# ...          ...        ...          ...                   ...         ...
# 5928        5928     1U1.DE        11.46  2022-12-23T00:00:00Z  2022-12-23
# 5929        5929     1U1.DE        11.45  2022-12-27T00:00:00Z  2022-12-27
# 5930        5930     1U1.DE        11.56  2022-12-28T00:00:00Z  2022-12-28
# 5931        5931     1U1.DE        11.68  2022-12-29T00:00:00Z  2022-12-29
# 5932        5932     1U1.DE        11.60  2022-12-30T00:00:00Z  2022-12-30
#
# [11866 rows x 5 columns]

# %%
for i in range(len(dfs_list)):
    df = dfs_list[i]
    if len(df) < 100:
        dfs_list.pop(i)

# %%
len(ls)
# Out:
# 96

# %%
len(dfs_list)
# Out:
# 1727

# %%
concated_df = pd.concat(dfs_list)

# %%
concated_df['Date'] = concated_df.Date.apply(lambda x: x[:10])

# %%
pivoted_df = concated_df.pivot(index='Date',columns='Instrument',values='Price Close')

# %%
pivoted_df = pivoted_df.sort_index()

# %%
pivoted_df.notna().sum(axis=1).plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
pivoted_df.fillna(method='ffill',limit=1).notna().sum(axis=1).plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
import datetime as dt
from dateutil.relativedelta import relativedelta

start_date = dt.date(2000,1,1)
end_date = dt.date(2023,1,1)
dates_days = [start_date]
i = 0
while (date := start_date + relativedelta(days=i+1)) <= end_date:
    dates_days.append(date)
    i +=1
str_dates = list(map(str,dates_days))

# %%
pivoted_df.sort_index()
# Out:
# Instrument  1COV.DE  1U1.DE   A2.MI  A3M.MC  AAAA.L^C21  AAH.AS^D08  \
# Date
# 1999-08-16      NaN     NaN     NaN     NaN         NaN         NaN
# 1999-12-08      NaN     NaN     NaN     NaN         NaN         NaN
# 1999-12-16      NaN     NaN     NaN     NaN         NaN         NaN
# 1999-12-21      NaN     NaN     NaN     NaN         NaN         NaN
# 1999-12-22      NaN     NaN     NaN     NaN         NaN         NaN
# ...             ...     ...     ...     ...         ...         ...
# 2022-12-23    36.33   11.46  1.2590   3.140         NaN         NaN
# 2022-12-27    36.78   11.45  1.2580   3.158         NaN         NaN
# 2022-12-28    36.94   11.56  1.2425   3.140         NaN         NaN
# 2022-12-29    36.88   11.68  1.2675   3.200         NaN         NaN
# 2022-12-30    36.55   11.60  1.2450   3.192         NaN         NaN
#
# Instrument     AAK.ST      AAL.L  AALB.AS  AB.L^G07  ...     YAR.OL  YIT.HE  \
# Date                                                 ...
# ...

# %%
dates_dict = pivoted_df.T.to_dict()

# %%
missing_dates = sorted(list(set(str_dates)-set(dates_dict.keys())))

# %%
missing_dates.index('2002-09-01')
# Out:
# 287

# %%
for i in missing_dates:
    dates_dict[i] = pd.NA

# %%
list(dates_dict.keys()).index('2002-09-01')
# Out:
# 6214

# %%
complete_df = pd.DataFrame(dates_dict).T

# %%
complete_df.sort_index()
# Out:
#            1COV.DE 1U1.DE   A2.MI A3M.MC AAAA.L^C21 AAH.AS^D08     AAK.ST  \
# 1999-08-16     NaN    NaN     NaN    NaN        NaN        NaN        NaN
# 1999-12-08     NaN    NaN     NaN    NaN        NaN        NaN        NaN
# 1999-12-16     NaN    NaN     NaN    NaN        NaN        NaN        NaN
# 1999-12-21     NaN    NaN     NaN    NaN        NaN        NaN        NaN
# 1999-12-22     NaN    NaN     NaN    NaN        NaN        NaN        NaN
# ...            ...    ...     ...    ...        ...        ...        ...
# 2022-12-28   36.94  11.56  1.2425   3.14        NaN        NaN  16.048986
# 2022-12-29   36.88  11.68  1.2675    3.2        NaN        NaN  16.158492
# 2022-12-30   36.55   11.6   1.245  3.192        NaN        NaN  15.967163
# 2022-12-31    <NA>   <NA>    <NA>   <NA>       <NA>       <NA>       <NA>
# 2023-01-01    <NA>   <NA>    <NA>   <NA>       <NA>       <NA>       <NA>
#
#                 AAL.L AALB.AS AB.L^G07  ...     YAR.OL YIT.HE YSO.LS ZALG.DE  \
# ...

# %%
type('hello') == str
# Out:
# True

# %%
for i in dates_dict.keys():
    if type(i) !=str:
        print(i,type(i))

# %%
complete_df.to_csv('../data/PriceClose_vertical/PriceClose_vertical.csv')

# %%
str_dates.index('2002-09-01')
# Out:
# 974

# %%
complete_df.loc['2002-09-01']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hugo.perezdealbeniz\AppData\Local\miniconda3\envs\refinitiv\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\hugo.perezdealbeniz\AppData\Local\miniconda3\envs\refinitiv\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\hugo.perezdealbeniz\AppData\Local\miniconda3\envs\refinitiv\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
complete_df.loc[dt.date(2002,9,1)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\hugo.perezdealbeniz\AppData\Local\miniconda3\envs\refinitiv\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File c:\Users\hugo.perezdealbeniz\AppData\Local\miniconda3\envs\refinitiv\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\hugo.perezdealbeniz\AppData\Local\miniconda3\envs\refinitiv\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
import json

# %%
with open(r'C:\Users\hugo.perezdealbeniz\Desktop\Ranking DIP European Equities\ReutersEikon\code_in_production\daily_constituents_filter.json') as file:
    daily_filter = json.load(file)

# %%
data = pd.DataFrame.from_dict(daily_filter,orient='index').stack()

# %%
data
# Out:
# 2023-01-01  0        WRT1V.HE
#             1         EVDG.DE
#             2      TIGOsdb.ST
#             3         VERB.VI
#             4        NOKIA.HE
#                       ...
# 2000-01-01  662         FTC.L
#             663        URW.AS
#             664       WBSV.VI
#             665       AKZO.AS
#             666        RIEN.S
# Length: 5249207, dtype: object

# %%
m = pd.crosstab(data.index.get_level_values(0),data).astype(bool)

# %%
m.to_csv(r'C:\Users\hugo.perezdealbeniz\Desktop\Ranking DIP European Equities\ReutersEikon\data\PriceClose_vertical\daily_filter_mask.csv')

# %%
import pandas as pd

# %%
precios_df = pd.read_csv(r'C:\Users\hugo.perezdealbeniz\Desktop\Ranking DIP European Equities\ReutersEikon\data\PriceClose_vertical\PriceClose_vertical.csv',index_col=0)

# %%
precios_df = precios_df.sort_index()

# %%
precios_df
# Out:
#             1COV.DE  1U1.DE   A2.MI  A3M.MC  AAAA.L^C21  AAH.AS^D08  \
# 1999-08-16      NaN     NaN     NaN     NaN         NaN         NaN
# 1999-12-08      NaN     NaN     NaN     NaN         NaN         NaN
# 1999-12-16      NaN     NaN     NaN     NaN         NaN         NaN
# 1999-12-21      NaN     NaN     NaN     NaN         NaN         NaN
# 1999-12-22      NaN     NaN     NaN     NaN         NaN         NaN
# ...             ...     ...     ...     ...         ...         ...
# 2022-12-28    36.94   11.56  1.2425   3.140         NaN         NaN
# 2022-12-29    36.88   11.68  1.2675   3.200         NaN         NaN
# 2022-12-30    36.55   11.60  1.2450   3.192         NaN         NaN
# 2022-12-31      NaN     NaN     NaN     NaN         NaN         NaN
# 2023-01-01      NaN     NaN     NaN     NaN         NaN         NaN
#
#                AAK.ST      AAL.L  AALB.AS  AB.L^G07  ...     YAR.OL  YIT.HE  \
# ...

# %%
precios_df.fillna(method='ffill',limit=1).dropna(how='all',axis=1)
# Out:
#             1COV.DE  1U1.DE   A2.MI  A3M.MC  AAAA.L^C21  AAH.AS^D08  \
# 1999-08-16      NaN     NaN     NaN     NaN         NaN         NaN
# 1999-12-08      NaN     NaN     NaN     NaN         NaN         NaN
# 1999-12-16      NaN     NaN     NaN     NaN         NaN         NaN
# 1999-12-21      NaN     NaN     NaN     NaN         NaN         NaN
# 1999-12-22      NaN     NaN     NaN     NaN         NaN         NaN
# ...             ...     ...     ...     ...         ...         ...
# 2022-12-28    36.94   11.56  1.2425   3.140         NaN         NaN
# 2022-12-29    36.88   11.68  1.2675   3.200         NaN         NaN
# 2022-12-30    36.55   11.60  1.2450   3.192         NaN         NaN
# 2022-12-31    36.55   11.60  1.2450   3.192         NaN         NaN
# 2023-01-01      NaN     NaN     NaN     NaN         NaN         NaN
#
#                AAK.ST      AAL.L  AALB.AS  AB.L^G07  ...     YAR.OL  YIT.HE  \
# ...

# %%
tmp = precios_df.fillna(method='ffill',limit=1).dropna(how='all',axis=1)#.drop_duplicates()

# %%
tmp.loc[tmp.duplicated()]
# Out:
#             1COV.DE  1U1.DE  A2.MI  A3M.MC  AAAA.L^C21  AAH.AS^D08  AAK.ST  \
# 2000-01-09      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2000-01-16      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2000-01-23      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2000-01-30      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2000-02-06      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# ...             ...     ...    ...     ...         ...         ...     ...
# 2022-12-11      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2022-12-18      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2022-12-25      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2022-12-26      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2023-01-01      NaN     NaN    NaN     NaN         NaN         NaN     NaN
#
# ...

# %%
precios_df.loc['2000-01-05'].notna().sum()
# Out:
# 1170

# %%
saturdays = str_dates[::7]
sundays = str_dates[1::7]

# %%
trading_str_dates = set(str_dates) - set(saturdays) - set(sundays)
trading_str_dates = sorted(list(trading_str_dates))

# %%
trading_str_dates
# Out:
# ['2000-01-03',
#  '2000-01-04',
#  '2000-01-05',
#  '2000-01-06',
#  '2000-01-07',
#  '2000-01-10',
#  '2000-01-11',
#  '2000-01-12',
#  '2000-01-13',
#  '2000-01-14',
#  '2000-01-17',
#  '2000-01-18',
#  '2000-01-19',
#  '2000-01-20',
#  '2000-01-21',
#  '2000-01-24',
#  '2000-01-25',
#  '2000-01-26',
#  '2000-01-27',
#  '2000-01-28',
#  '2000-01-31',
#  '2000-02-01',
#  '2000-02-02',
#  '2000-02-03',
#  '2000-02-04',
#  '2000-02-07',
#  '2000-02-08',
#  '2000-02-09',
#  '2000-02-10',
#  '2000-02-11',
#  '2000-02-14',
#  '2000-02-15',
#  '2000-02-16',
#  '2000-02-17',
#  '2000-02-18',
#  '2000-02-21',
#  '2000-02-22',
#  '2000-02-23',
#  '2000-02-24',
#  '2000-02-25',
#  '2000-02-28',
#  '2000-02-29',
#  '2000-03-01',
#  '2000-03-02',
#  '2000-03-03',
#  '2000-03-06',
#  '2000-03-07',
#  '2000-03-08',
#  '2000-03-09',
#  '2000-03-10',
#  '2000-03-13',
#  '2000-03-14',
#  '2000-03-15',
#  '2000-03-16',
#  '2000-03-17',
#  '2000-03-20',
#  '2000-03-21',
#  '2000-03-22',
# ...

# %%
tmp = precios_df.loc[trading_str_dates]
tmp.loc[tmp.duplicated()]
# Out:
#             1COV.DE  1U1.DE  A2.MI  A3M.MC  AAAA.L^C21  AAH.AS^D08  AAK.ST  \
# 2000-12-26      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2001-01-01      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2001-04-16      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2001-12-25      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2001-12-26      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# ...             ...     ...    ...     ...         ...         ...     ...
# 2021-04-02      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2021-04-05      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2022-04-15      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2022-04-18      NaN     NaN    NaN     NaN         NaN         NaN     NaN
# 2022-12-26      NaN     NaN    NaN     NaN         NaN         NaN     NaN
#
# ...

# %%
tmp.notna()
# Out:
#             1COV.DE     1U1.DE     A2.MI  A3M.MC  AAAA.L^C21  AAH.AS^D08  \
# 2000-01-03      NaN   6.908680  3.766606     NaN         NaN       24.55
# 2000-01-04      NaN   6.812055  3.628454     NaN         NaN       23.20
# 2000-01-05      NaN   6.570493  3.587009     NaN         NaN       22.60
# 2000-01-06      NaN   6.667118  3.695556     NaN         NaN       22.33
# 2000-01-07      NaN   6.667118  3.831734     NaN         NaN       22.59
# ...             ...        ...       ...     ...         ...         ...
# 2022-12-23    36.33  11.460000  1.259000   3.140         NaN         NaN
# 2022-12-27    36.78  11.450000  1.258000   3.158         NaN         NaN
# 2022-12-28    36.94  11.560000  1.242500   3.140         NaN         NaN
# 2022-12-29    36.88  11.680000  1.267500   3.200         NaN         NaN
# 2022-12-30    36.55  11.600000  1.245000   3.192         NaN         NaN
#
#                AAK.ST      AAL.L  AALB.AS   AB.L^G07  ...     YAR.OL  \
# ...
