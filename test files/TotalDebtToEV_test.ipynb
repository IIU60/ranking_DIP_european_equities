# %%
from code_in_production.app_functions import get_data, rank_data, plot_NAV_absoluto,plot_NAV_relativo,plot_rentabilidad_media,plot_sharpe,plot_Volatilidad
import pandas as pd

# %%
#pivoted_df,errors = get_data(['TR.TotalDebtToEV','TR.TotalDebtToEV.date'],desired_field_name='TotalDebtToEV')

# %%
pivoted_df = pd.read_csv('raw_TotalDebtToEV.csv')
pivoted_df.columns
# Out:
# Index(['Unnamed: 0', 'Instrument', 'Date', 'CallDate',
#        'Total Debt To Enterprise Value (Daily Time Series Ratio)'],
#       dtype='object')

# %%
pivoted_df.rename(columns={'Total Debt To Enterprise Value (Daily Time Series Ratio)':'TotalDebtToEV'},inplace = True)
pivoted_df = pivoted_df.pivot(index = 'CallDate',columns='Instrument',values= 'TotalDebtToEV')
pivoted_df
# Out:
# Instrument    1COV.DE  1U1.DE      A2.MI  A3M.MC  AAAA.L^C21  AAH.AS^D08  \
# CallDate
# 2000-01-01        NaN     NaN        NaN     NaN         NaN         NaN
# 2000-02-01        NaN     NaN        NaN     NaN         NaN         NaN
# 2000-03-01        NaN     NaN        NaN     NaN         NaN         NaN
# 2000-04-01        NaN     NaN        NaN     NaN         NaN         NaN
# 2000-05-01        NaN     NaN        NaN     NaN         NaN         NaN
# ...               ...     ...        ...     ...         ...         ...
# 2022-09-01  36.978266     NaN  71.911221     NaN         NaN         NaN
# 2022-10-01  37.011747     NaN  74.640774     NaN         NaN         NaN
# 2022-11-01  33.705813     NaN  71.312614     NaN         NaN         NaN
# 2022-12-01  31.614185     NaN  67.236580     NaN         NaN         NaN
# 2023-01-01  31.994109     NaN  81.211627     NaN         NaN         NaN
#
# Instrument     AAK.ST      AAL.L    AALB.AS  AB.L^G07  ...     YAR.OL  YIT.HE  \
# ...

# %%
ruta_precios = 'Z:\Interés Departamental\Model Portfolio\Hugo\Ranking DIP European Equities\Reuters Eikon\data\Final Data\PriceClose.csv'
rentabilidades_dict,notna_graph = rank_data(pivoted_df, ruta_precios)

# %%
graph_NAV_absoluto = plot_NAV_absoluto(rentabilidades_dict)
graph_NAV_relativo = plot_NAV_relativo(rentabilidades_dict)
graph_rentabilidad_media = plot_rentabilidad_media(rentabilidades_dict)
graph_volatilidad = plot_Volatilidad(rentabilidades_dict)
graph_sharpe = plot_sharpe(rentabilidades_dict)

# %%
graph_volatilidad

# %%
import sys

# %%
sys.path
# Out:
# ['z:\\Interés Departamental\\Model Portfolio\\Hugo\\Ranking DIP European Equities\\Reuters Eikon',
#  'c:\\Users\\hugo.perezdealbeniz\\AppData\\Local\\miniconda3\\envs\\refinitiv\\python310.zip',
#  'c:\\Users\\hugo.perezdealbeniz\\AppData\\Local\\miniconda3\\envs\\refinitiv\\DLLs',
#  'c:\\Users\\hugo.perezdealbeniz\\AppData\\Local\\miniconda3\\envs\\refinitiv\\lib',
#  'c:\\Users\\hugo.perezdealbeniz\\AppData\\Local\\miniconda3\\envs\\refinitiv',
#  '',
#  'c:\\Users\\hugo.perezdealbeniz\\AppData\\Local\\miniconda3\\envs\\refinitiv\\lib\\site-packages',
#  'c:\\Users\\hugo.perezdealbeniz\\AppData\\Local\\miniconda3\\envs\\refinitiv\\lib\\site-packages\\win32',
#  'c:\\Users\\hugo.perezdealbeniz\\AppData\\Local\\miniconda3\\envs\\refinitiv\\lib\\site-packages\\win32\\lib',
#  'c:\\Users\\hugo.perezdealbeniz\\AppData\\Local\\miniconda3\\envs\\refinitiv\\lib\\site-packages\\Pythonwin']
